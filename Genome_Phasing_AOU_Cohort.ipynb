# %% [markdown]
# # Phasing Full AOU Participant Cohort

# %% [markdown]
# Purpose: Phasing entire AOU cohort for local ancestry and admixture inference

# %%
#Importing packages relevant for notebook
from datetime import datetime
import os
import subprocess

# %%
#Assigning bucket address to a variable
my_bucket = os.getenv('WORKSPACE_BUCKET')
my_bucket
# Out:
# 'gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b'

# %%
USER_NAME = os.getenv('OWNER_EMAIL').split('@')[0].replace('.','-')

# Save this Python variable as an environment variable so that its easier to use within %%bash cells.
# %env USER_NAME={USER_NAME}
# Out:
# env: USER_NAME=nmshahir

# %%
# !gsutil ls -lh gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test
# Out:
#  58.97 GiB  2024-04-04T17:34:24Z  gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_QC_only_sort.vcf.gz
#   2.39 MiB  2024-04-04T21:26:01Z  gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_QC_only_sort.vcf.gz.tbi
#   1.92 GiB  2024-04-15T00:59:09Z  gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr13.b38.sorted.phased.bcf
# 788.08 MiB  2024-04-09T20:34:40Z  gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr22.b38.sorted.phased.bcf
#        0 B  2024-04-03T17:43:13Z  gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/test.txt
# TOTAL: 5 objects, 66209472624 bytes (61.66 GiB)

# %%
# %%bash
#
# dsub --help
# Out:
# usage: /opt/conda/bin/dsub [-h] [--provider PROVIDER] [--version VERSION]
#                            [--unique-job-id] [--name NAME]
#                            [--tasks [FILE M-N ...]] [--image IMAGE]
#                            [--dry-run] [--command COMMAND] [--script SCRIPT]
#                            [--env [KEY=VALUE ...]] [--label [KEY=VALUE ...]]
#                            [--input [KEY=REMOTE_PATH ...]]
#                            [--input-recursive [KEY=REMOTE_PATH ...]]
#                            [--output [KEY=REMOTE_PATH ...]]
#                            [--output-recursive [KEY=REMOTE_PATH ...]]
#                            [--user USER] [--user-project USER_PROJECT]
#                            [--mount [KEY=PATH_SPEC ...]] [--wait]
#                            [--retries RETRIES] [--poll-interval POLL_INTERVAL]
#                            [--after AFTER [AFTER ...]] [--skip] [--summary]
#                            [--min-cores MIN_CORES] [--min-ram MIN_RAM]
#                            [--disk-size DISK_SIZE] [--logging LOGGING]
#                            [--project PROJECT]
#                            [--boot-disk-size BOOT_DISK_SIZE]
#                            [--preemptible [PREEMPTIBLE]]
#                            [--zones ZONES [ZONES ...]]
#                            [--scopes SCOPES [SCOPES ...]]
#                            [--accelerator-type ACCELERATOR_TYPE]
#                            [--accelerator-count ACCELERATOR_COUNT]
#                            [--credentials-file CREDENTIALS_FILE]
#                            [--regions REGIONS [REGIONS ...]]
#                            [--machine-type MACHINE_TYPE]
#                            [--cpu-platform CPU_PLATFORM] [--network NETWORK]
#                            [--subnetwork SUBNETWORK] [--use-private-address]
#                            [--timeout TIMEOUT] [--log-interval LOG_INTERVAL]
#                            [--ssh] [--service-account SERVICE_ACCOUNT]
#                            [--disk-type DISK_TYPE]
#                            [--enable-stackdriver-monitoring]
#                            [--block-external-network] [--location LOCATION]
#
# options:
#   -h, --help            show this help message and exit
#   --provider PROVIDER   Job service provider. Valid values are "google-v2"
#                         (Google's Pipeline API v2alpha1), "google-cls-v2"
#                         (Google's Pipelines API v2beta), "google-batch"
#                         (Google's Batch API v1alpha1), and "local" (local
#                         Docker execution). "test-*" providers are for testing
#                         purposes only. (default: google-v2)
#   --version VERSION, -v VERSION
#                         Print the dsub version and exit.
#   --unique-job-id       Experimental: create a unique 32 character UUID for
#                         the dsub job-id using
#                         https://docs.python.org/3/library/uuid.html. (default:
#                         False)
#   --name NAME           Name for the job. Defaults to the script name or first
#                         token of the --command if specified.
#   --tasks [FILE M-N ...]
#                         Path to a file of tab separated values (TSV) for task
#                         parameters. The file may be located in the local
#                         filesystem or in a Google Cloud Storage bucket. The
#                         first line is a list of column headers specifying an
#                         --env, --input, --input-recursive, --output or
#                         --output-recursive variable, and each subsequent line
#                         specifies the values for a task. Optionally specify
#                         tasks from the file to submit. Can take the form "m",
#                         "m-", or "m-n" where m and n are task numbers starting
#                         at 1. (default: None)
#   --image IMAGE         Image name from Docker Hub, Google Container
#                         Repository, or other Docker image service. The task
#                         must have READ access to the image. (default:
#                         ubuntu:14.04)
#   --dry-run             Print the task(s) that would be run and then exit.
#                         (default: False)
#   --command COMMAND     Command to run inside the job's Docker container. This
#                         argument or the --script argument must be provided.
#   --script SCRIPT       Path to a script that is located in the local file
#                         system or inside a Google Cloud Storage bucket. This
#                         script will be run inside the job's Docker container.
#                         This argument or the --command argument must be
#                         provided.
#   --env [KEY=VALUE ...]
#                         Environment variables for the script's execution
#                         environment
#   --label [KEY=VALUE ...]
#                         Labels to associate to the job.
#   --input [KEY=REMOTE_PATH ...]
#                         Input path arguments to localize into the script's
#                         execution environment
#   --input-recursive [KEY=REMOTE_PATH ...]
#                         Input path arguments to localize recursively into the
#                         script's execution environment
#   --output [KEY=REMOTE_PATH ...]
#                         Output path arguments to de-localize from the script's
#                         execution environment
#   --output-recursive [KEY=REMOTE_PATH ...]
#                         Output path arguments to de-localize recursively from
#                         the script's execution environment
#   --user USER, -u USER  User submitting the dsub job, defaults to the current
#                         OS user.
#   --user-project USER_PROJECT
#                         Specify a user project to be billed for all requests
#                         to Google Cloud Storage (logging, localization,
#                         delocalization, mounting). This flag exists to support
#                         accessing Requester Pays buckets (default: None)
#   --mount [KEY=PATH_SPEC ...]
#                         Mount a resource such as a bucket, disk, or directory
#                         into your Docker container
#   --wait                Wait for the job to finish all its tasks. (default:
#                         False)
#   --retries RETRIES     Number of retries to perform on failed tasks.
#                         (default: 0)
#   --poll-interval POLL_INTERVAL
#                         Polling interval (in seconds) for checking job status
#                         when --wait or --after are set. (default: 10)
#   --after AFTER [AFTER ...]
#                         Job ID(s) to wait for before starting this job.
#   --skip                Do not submit the job if all output specified using
#                         the --output and --output-recursive parameters already
#                         exist. Note that wildcard and recursive outputs cannot
#                         be strictly verified. See the documentation for
#                         details. (default: False)
#   --summary             During the --wait loop, display a summary of the
#                         results, grouped by (job, status). (default: False)
#   --min-cores MIN_CORES
#                         Minimum CPU cores for each job. The default is
#                         provider-specific. The google-v2 provider default is 1
#                         core. The local provider does not allocate resources,
#                         but uses available resources of your machine.
#   --min-ram MIN_RAM     Minimum RAM per job in GB. The default is provider-
#                         specific. The google-v2 provider default is 3.75 GB.
#                         The local provider does not allocate resources, but
#                         uses available resources of your machine.
#   --disk-size DISK_SIZE
#                         Size (in GB) of data disk to attach for each job
#                         (default: 200)
#   --logging LOGGING     Cloud Storage path to send logging output (either a
#                         folder, or file ending in ".log")
#
# google-common:
#   Options common to the "google-cls-v2", "google-v2" and
#           "google-batch" providers
#
#   --project PROJECT     Cloud project ID in which to run the job
#   --boot-disk-size BOOT_DISK_SIZE
#                         Size (in GB) of the boot disk (default: 10)
#   --preemptible [PREEMPTIBLE]
#                         If --preemptible is given without a number, enables
#                         preemptible VMs for all attempts for all tasks. If a
#                         number value N is used, enables preemptible VMs for up
#                         to N attempts for each task. Defaults to not using
#                         preemptible VMs.
#   --zones ZONES [ZONES ...]
#                         List of Google Compute Engine zones.
#   --scopes SCOPES [SCOPES ...]
#                         Space-separated scopes for Google Compute Engine
#                         instances. If unspecified, provider will use 'https://
#                         www.googleapis.com/auth/bigquery,https://www.googleapi
#                         s.com/auth/compute,https://www.googleapis.com/auth/dev
#                         storage.full_control,https://www.googleapis.com/auth/g
#                         enomics,https://www.googleapis.com/auth/logging.write,
#                         https://www.googleapis.com/auth/monitoring.write'
#   --accelerator-type ACCELERATOR_TYPE
#                         The Compute Engine accelerator type. See
#                         https://cloud.google.com/compute/docs/gpus/ for
#                         supported GPU types. Only NVIDIA GPU accelerators are
#                         currently supported. If an NVIDIA GPU is attached, the
#                         required runtime libraries will be made available to
#                         all containers under /usr/local/nvidia. Each version
#                         of Container-Optimized OS image (used by the Pipelines
#                         API) has a default supported NVIDIA GPU driver
#                         version. See https://cloud.google.com/container-
#                         optimized-os/docs/how-to/run-gpus#install Note that
#                         attaching a GPU increases the worker VM startup time
#                         by a few minutes. (default: None)
#   --accelerator-count ACCELERATOR_COUNT
#                         The number of accelerators of the specified type to
#                         attach. By specifying this parameter, you will
#                         download and install the following third-party
#                         software onto your job's Compute Engine instances:
#                         NVIDIA(R) Tesla(R) drivers and NVIDIA(R) CUDA toolkit.
#                         (default: 0)
#   --credentials-file CREDENTIALS_FILE
#                         Path to a local file with JSON credentials for a
#                         service account.
#   --regions REGIONS [REGIONS ...]
#                         List of Google Compute Engine regions. Only one of
#                         --zones and --regions may be specified.
#   --machine-type MACHINE_TYPE
#                         Provider-specific machine type (default: None)
#   --cpu-platform CPU_PLATFORM
#                         The CPU platform to request. Supported values can be
#                         found at https://cloud.google.com/compute/docs/instanc
#                         es/specify-min-cpu-platform (default: None)
#   --network NETWORK     The Compute Engine VPC network name to attach the VM's
#                         network interface to. The value will be prefixed with
#                         global/networks/ unless it contains a /, in which case
#                         it is assumed to be a fully specified network resource
#                         URL. (default: None)
#   --subnetwork SUBNETWORK
#                         The name of the Compute Engine subnetwork to attach
#                         the instance to. (default: None)
#   --use-private-address
#                         If set to true, do not attach a public IP address to
#                         the VM. (default: False)
#   --timeout TIMEOUT     The maximum amount of time to give the task to
#                         complete. This includes the time spent waiting for a
#                         worker to be allocated. Time can be listed using a
#                         number followed by a unit. Supported units are s
#                         (seconds), m (minutes), h (hours), d (days), w
#                         (weeks). The provider-specific default is 7 days.
#                         Example: '7d' (7 days).
#   --log-interval LOG_INTERVAL
#                         The amount of time to sleep between copies of log
#                         files from the task to the logging path. Time can be
#                         listed using a number followed by a unit. Supported
#                         units are s (seconds), m (minutes), h (hours).
#                         Example: '5m' (5 minutes). Default is '1m'.
#   --ssh                 If set to true, start an ssh container in the
#                         background to allow you to log in using SSH and debug
#                         in real time. (default: False)
#   --service-account SERVICE_ACCOUNT
#                         Email address of the service account to be authorized
#                         on the Compute Engine VM for each job task. If not
#                         specified, the default Compute Engine service account
#                         for the project will be used.
#   --disk-type DISK_TYPE
#                         The disk type to use for the data disk. Valid values
#                         are pd-standard pd-ssd and local-ssd. The default
#                         value is pd-standard.
#   --enable-stackdriver-monitoring
#                         If set to true, enables Stackdriver monitoring on the
#                         VM. (default: False)
#   --block-external-network
#                         If set to true, prevents the container for the user's
#                         script/command from accessing the external network.
#                         (default: False)
#
# "google-cls-v2" provider options:
#   See also the "google-common" options listed above
#
#   --location LOCATION   Specifies the Google Cloud region to which the
#                         pipeline request will be sent and where operation
#                         metadata will be stored. The associated dsub task may
#                         be executed in another region if the --regions or
#                         --zones arguments are specified. (default: us-
#                         central1)
#
# Provider-required arguments:
#   google-batch: ['project', 'logging']
#   google-cls-v2: ['project', 'logging']
#   google-v2: ['project', 'logging']
#   test-fails: []
#   local: ['logging']

# %% [markdown]
# # Files Needed

# %% [markdown]
# |File | File Type | Formatting Notes|
# |-----|-----------|------------------|
# |Query file | VCF file of participants to be phased| 1) AC field is needed for SHAPEIT to run. If it is not within the VCF, run "bcftools +fill-AN-AC <query_file.vcf>  -Oz -o <query_file_w_AC.vcf.gz>  -- -t all"; 2) Additionally the file must also be sorted and indexed|
# |Genetic map files| gmap(.gz) |SHAPEIT group provides these. Use "wget https://github.com/odelaneau/shapeit5/raw/main/resources/maps/b38/" to acquire them |

# %% [markdown]
# # Final Version

# %% [markdown]
# First, we'll create the script for running SHAPEIT

# %%
# %%writefile phase_aou.sh
# #!/bin/bash
# set -o errexit
# set -o nounset
# # Phasing
# phase_common_static --input "${input_vcf}/AOU_QC_only_sort.vcf.gz" --region ${chrom} --map "${gene_map}/chr${chrom}.b38.gmap.gz" --output "${out_path}/AOU_chr${chrom}.b38.sorted.phased.bcf" --thread 8
# Out:
# Writing phase_aou.sh

# %% [markdown]
# Explanation of parts:
#
# {input_vcf} - path to the query vcf, this is the file we're going to be phasing.
#
# {chrom} - corresponds to the chromosome number
#
# {gene_map} - corresponds to the path to the genetic map files
#
# {out_path} - corresponds to the path where we want the output files to reside
#
# All of these paths will be defined in our dsub script at submission.

# %% [markdown]
# Next, we'll copy our script to our workspace bucket. In this instance, I've sent it to the "scripts" directory in my workspace bucket.

# %%
# !gsutil cp phase_aou.sh ${WORKSPACE_BUCKET}/scripts/phase_aou.sh
# Out:
# Copying file://phase_aou.sh [Content-Type=text/x-sh]...
# / [1 files][  252.0 B/  252.0 B]
# Operation completed over 1 objects/252.0 B.

# %% [markdown]
# Below is a dsub job that we'll use to run SHAPEIT on a cloud virtual machine (VM). For a more robust overview of dsub, I strongly recommend reviewing their notebooks on how to use dsub on the AOU researcher workbench here: https://workbench.researchallofus.org/workspaces/aou-rw-6221d5ec/howtousedsubintheresearcherworkbenchv7/data .
#
# For the dsub job out lined here the relevant parts are that in order to avoid submitting a job for each chromosome manually, we implement a loop interating from 1 to 22 to submit a job for chromosome for phasing. Since SHAPEIT5 is not part of the default terra-jupyter image, instead we use a SHAPEIT5 container "gcr.io/boxwood-sandbox-353200/shapeit5_2023-05-05" that I've uploaded to the GCR. Note: The GCR is in the process of being depreciated and moving to Artifact Registry. This will be updated when the transition finishes.

# %%
# %%bash --out aou_phase
# source ~/aou_dsub.bash # This file was created via notebook 01_dsub_setup.ipynb.
#
# BASH_SCRIPT="gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/scripts/phase_aou.sh"
#
#
# LOWER=1
# UPPER=23
# for ((chromo=$LOWER;chromo<$UPPER;chromo+=1))
# do
# aou_dsub \
#   --image gcr.io/boxwood-sandbox-353200/shapeit5_2023-05-05 \
#   --disk-size 512 \
#   --boot-disk-size 100 \
#   --min-ram 512 \
#   --logging "${WORKSPACE_BUCKET}/data/logging" \
#   --input-recursive input_vcf="${WORKSPACE_BUCKET}/data/phase_test" \
#   --input-recursive gene_map="${WORKSPACE_BUCKET}/gnomad_ref" \
#   --output-recursive out_path="${WORKSPACE_BUCKET}/data/phase_test" \
#   --env chrom=${chromo} \
#   --script "${BASH_SCRIPT}"
# done
# Out:
# Job properties:
#   job-id: phase-aou--nmshahir--240416-010609-90
#   job-name: phase-aou
#   user-id: nmshahir
# Provider internal-id (operation): projects/284833138454/locations/us-central1/operations/14666657719332510908
# Launched job-id: phase-aou--nmshahir--240416-010609-90
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-f195c3ba --location us-central1 --jobs 'phase-aou--nmshahir--240416-010609-90' --users 'nmshahir' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-f195c3ba --location us-central1 --jobs 'phase-aou--nmshahir--240416-010609-90' --users 'nmshahir'
# Job properties:
#   job-id: phase-aou--nmshahir--240416-010612-06
#   job-name: phase-aou
#   user-id: nmshahir
# Provider internal-id (operation): projects/284833138454/locations/us-central1/operations/695032650448920075
# Launched job-id: phase-aou--nmshahir--240416-010612-06
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-f195c3ba --location us-central1 --jobs 'phase-aou--nmshahir--240416-010612-06' --users 'nmshahir' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-f195c3ba --location us-central1 --jobs 'phase-aou--nmshahir--240416-010612-06' --users 'nmshahir'
# Job properties:
#   job-id: phase-aou--nmshahir--240416-010614-01
#   job-name: phase-aou
#   user-id: nmshahir
# Provider internal-id (operation): projects/284833138454/locations/us-central1/operations/16180994325813204824
# Launched job-id: phase-aou--nmshahir--240416-010614-01
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-f195c3ba --location us-central1 --jobs 'phase-aou--nmshahir--240416-010614-01' --users 'nmshahir' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-f195c3ba --location us-central1 --jobs 'phase-aou--nmshahir--240416-010614-01' --users 'nmshahir'
# Job properties:
#   job-id: phase-aou--nmshahir--240416-010615-92
#   job-name: phase-aou
#   user-id: nmshahir
# Provider internal-id (operation): projects/284833138454/locations/us-central1/operations/12548285453064590511
# Launched job-id: phase-aou--nmshahir--240416-010615-92
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-f195c3ba --location us-central1 --jobs 'phase-aou--nmshahir--240416-010615-92' --users 'nmshahir' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-f195c3ba --location us-central1 --jobs 'phase-aou--nmshahir--240416-010615-92' --users 'nmshahir'
# Job properties:
#   job-id: phase-aou--nmshahir--240416-010617-89
#   job-name: phase-aou
#   user-id: nmshahir
# Provider internal-id (operation): projects/284833138454/locations/us-central1/operations/2295224600298890907
# Launched job-id: phase-aou--nmshahir--240416-010617-89
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-f195c3ba --location us-central1 --jobs 'phase-aou--nmshahir--240416-010617-89' --users 'nmshahir' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-f195c3ba --location us-central1 --jobs 'phase-aou--nmshahir--240416-010617-89' --users 'nmshahir'
# Job properties:
#   job-id: phase-aou--nmshahir--240416-010619-77
#   job-name: phase-aou
#   user-id: nmshahir
# Provider internal-id (operation): projects/284833138454/locations/us-central1/operations/15781615346477255472
# Launched job-id: phase-aou--nmshahir--240416-010619-77
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-f195c3ba --location us-central1 --jobs 'phase-aou--nmshahir--240416-010619-77' --users 'nmshahir' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-f195c3ba --location us-central1 --jobs 'phase-aou--nmshahir--240416-010619-77' --users 'nmshahir'
# Job properties:
#   job-id: phase-aou--nmshahir--240416-010621-73
#   job-name: phase-aou
#   user-id: nmshahir
# Provider internal-id (operation): projects/284833138454/locations/us-central1/operations/16385238560454898245
# Launched job-id: phase-aou--nmshahir--240416-010621-73
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-f195c3ba --location us-central1 --jobs 'phase-aou--nmshahir--240416-010621-73' --users 'nmshahir' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-f195c3ba --location us-central1 --jobs 'phase-aou--nmshahir--240416-010621-73' --users 'nmshahir'
# Job properties:
#   job-id: phase-aou--nmshahir--240416-010623-66
#   job-name: phase-aou
#   user-id: nmshahir
# Provider internal-id (operation): projects/284833138454/locations/us-central1/operations/6597179824237372606
# Launched job-id: phase-aou--nmshahir--240416-010623-66
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-f195c3ba --location us-central1 --jobs 'phase-aou--nmshahir--240416-010623-66' --users 'nmshahir' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-f195c3ba --location us-central1 --jobs 'phase-aou--nmshahir--240416-010623-66' --users 'nmshahir'

# %%
# !dstat --provider google-cls-v2 --project terra-vpc-sc-f195c3ba --location us-central1 --jobs 'phase-aou--nmshahir--240416-010623-66' --users 'nmshahir' --status '*' --full
# Out:
# - create-time: '2024-04-16 01:06:23.751820'
#   dsub-version: v0-4-10
#   end-time: '2024-04-16 05:57:55.399194'
#   envs:
#     chrom: '21'
#   events:
#   - name: start
#     start-time: 2024-04-16 01:06:29.805475+00:00
#   - name: pulling-image
#     start-time: 2024-04-16 01:07:20.042320+00:00
#   - name: localizing-files
#     start-time: 2024-04-16 01:07:53.537266+00:00
#   - name: running-docker
#     start-time: 2024-04-16 01:29:59.713134+00:00
#   - name: delocalizing-files
#     start-time: 2024-04-16 05:57:45.230557+00:00
#   - name: ok
#     start-time: 2024-04-16 05:57:55.399194+00:00
#   input-recursives:
#     input_vcf: gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test
#     ref_map: gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/gnomad_ref
#   inputs: {}
#   internal-id: projects/284833138454/locations/us-central1/operations/6597179824237372606
#   job-id: phase-aou--nmshahir--240416-010623-66
#   job-name: phase-aou
#   labels: {}
#   last-update: '2024-04-16 05:57:55.399194'
#   logging: gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/logging/phase-aou--nmshahir--240416-010623-66.log
#   mounts: {}
#   output-recursives:
#     out_path: gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test
#   outputs: {}
#   provider: google-cls-v2
#   provider-attributes:
#     accelerators: []
#     block-external-network: null
#     boot-disk-size: 100
#     cpu_platform: ''
#     disk-size: 512
#     disk-type: pd-standard
#     enable-stackdriver-monitoring: false
#     instance-name: google-pipelines-worker-d5f845461f3056e9cf69f306bc795fe8
#     machine-type: custom-80-524288
#     network: network
#     preemptible: false
#     regions:
#     - us-central1
#     service-account: pet-2696974385960d8c50f37@terra-vpc-sc-f195c3ba.iam.gserviceaccount.com
#     ssh: false
#     subnetwork: subnetwork
#     use_private_address: false
#     volumes: []
#     zone: us-central1-c
#     zones: []
#   script: |
#     #!/bin/bash
#     set -o errexit
#     set -o nounset
#     # Phasing
#     phase_common_static --input "${input_vcf}/AOU_QC_only_sort.vcf.gz" --region ${chrom} --map "${ref_map}/chr${chrom}.b38.gmap.gz" --output "${out_path}/AOU_chr${chrom}.b38.sorted.phased.bcf" --thread 8
#   script-name: phase_aou.sh
#   start-time: '2024-04-16 01:06:29.805475'
#   status: SUCCESS
#   status-detail: Success
#   status-message: Success
#   user-id: nmshahir
#   user-project: terra-vpc-sc-f195c3ba

# %%
# !gsutil ls ${WORKSPACE_BUCKET}/data/phase_test
# Out:
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_QC_only_sort.vcf.gz
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_QC_only_sort.vcf.gz.tbi
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr1.b38.sorted.phased.bcf
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr1.b38.sorted.phased.bcf.csi
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr10.b38.sorted.phased.bcf
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr10.b38.sorted.phased.bcf.csi
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr11.b38.sorted.phased.bcf
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr11.b38.sorted.phased.bcf.csi
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr12.b38.sorted.phased.bcf
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr12.b38.sorted.phased.bcf.csi
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr13.b38.sorted.phased.bcf
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr14.b38.sorted.phased.bcf
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr14.b38.sorted.phased.bcf.csi
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr15.b38.sorted.phased.bcf
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr15.b38.sorted.phased.bcf.csi
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr16.b38.sorted.phased.bcf
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr16.b38.sorted.phased.bcf.csi
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr17.b38.sorted.phased.bcf
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr17.b38.sorted.phased.bcf.csi
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr18.b38.sorted.phased.bcf
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr18.b38.sorted.phased.bcf.csi
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr19.b38.sorted.phased.bcf
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr19.b38.sorted.phased.bcf.csi
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr2.b38.sorted.phased.bcf
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr2.b38.sorted.phased.bcf.csi
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr20.b38.sorted.phased.bcf
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr20.b38.sorted.phased.bcf.csi
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr21.b38.sorted.phased.bcf
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr21.b38.sorted.phased.bcf.csi
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr22.b38.sorted.phased.bcf
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr3.b38.sorted.phased.bcf
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr3.b38.sorted.phased.bcf.csi
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr4.b38.sorted.phased.bcf
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr4.b38.sorted.phased.bcf.csi
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr5.b38.sorted.phased.bcf
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr5.b38.sorted.phased.bcf.csi
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr6.b38.sorted.phased.bcf
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr6.b38.sorted.phased.bcf.csi
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr7.b38.sorted.phased.bcf
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr7.b38.sorted.phased.bcf.csi
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr8.b38.sorted.phased.bcf
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr8.b38.sorted.phased.bcf.csi
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr9.b38.sorted.phased.bcf
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/AOU_chr9.b38.sorted.phased.bcf.csi
# gs://fc-secure-9bc86de4-cb77-407c-82c4-de33c6265a3b/data/phase_test/test.txt

# %%
# %%bash
#
# dstat \
#     --provider google-cls-v2 \
#     --project "${GOOGLE_PROJECT}" \
#     --location us-central1 \
#     --users "${USER_NAME}" \
#     --jobs '*' \
#     --status '*'
# Out:
# Job Name         Status                                      Last Update
# ---------------  ------------------------------------------  --------------
# phase-aou        Success                                     04-17 17:38:02
# phase-aou        Success                                     04-17 18:06:52
# phase-aou        Success                                     04-17 17:34:11
# phase-aou        Success                                     04-17 16:50:45
# phase-aou        Success                                     04-17 18:54:24
# phase-aou        Success                                     04-17 19:44:34
# phase-aou        Success                                     04-18 15:20:53
# phase-aou        Success                                     04-17 21:12:31
# phase-aou        Success                                     04-18 00:17:45
# phase-aou        Success                                     04-18 01:39:05
# phase-aou        Success                                     04-18 06:03:30
# phase-aou        Success                                     04-18 02:48:30
# phase-aou        creating instance: inserting instance: ...  04-17 02:11:16
# phase-aou        creating instance: inserting instance: ...  04-17 02:11:12
# phase-aou        creating instance: inserting instance: ...  04-17 02:10:54
# phase-aou        creating instance: inserting instance: ...  04-17 02:10:53
# phase-aou        creating instance: inserting instance: ...  04-17 02:10:53
# phase-aou        creating instance: inserting instance: ...  04-17 02:10:53
# phase-aou        creating instance: inserting instance: ...  04-17 02:10:53
# phase-aou        creating instance: inserting instance: ...  04-17 02:10:53
# phase-aou        creating instance: inserting instance: ...  04-17 02:10:53
# phase-aou        creating instance: inserting instance: ...  04-17 02:10:53
# phase-aou        creating instance: inserting instance: ...  04-17 02:10:53
# phase-aou        creating instance: inserting instance: ...  04-17 02:10:53
# phase-aou        Success                                     04-16 05:57:55
# phase-aou        Success                                     04-16 09:21:08
# phase-aou        Success                                     04-16 08:25:57
# phase-aou        Success                                     04-16 10:52:40
# phase-aou        Success                                     04-16 11:43:01
# phase-aou        Success                                     04-16 12:03:51
# phase-aou        Success                                     04-16 11:10:18
# phase-aou        Success                                     04-16 11:18:52
# phase-aou        creating instance: inserting instance: ...  04-15 23:24:08
# phase-aou        creating instance: inserting instance: ...  04-15 23:24:08
# phase-aou        creating instance: inserting instance: ...  04-15 23:24:08
# phase-aou        creating instance: inserting instance: ...  04-15 23:24:08
# phase-aou        creating instance: inserting instance: ...  04-15 23:24:08
# phase-aou        creating instance: inserting instance: ...  04-15 23:24:08
# phase-aou        creating instance: inserting instance: ...  04-15 23:24:08
# phase-aou        creating instance: inserting instance: ...  04-15 23:24:07
# phase-13-aou...  Success                                     04-15 00:59:12
# phase-13-aou...  Stopped running "user-command": exit st...  04-14 04:11:57
# phase-22-aou...  Success                                     04-09 20:34:43
# phase-22-aou...  Stopped running "user-command": exit st...  04-09 15:00:31
# phase-22-aou...  The operation was cancelled                 04-09 14:07:51
# phase-13-aou...  Stopped running "user-command": exit st...  04-09 10:58:51
# phase-22-aou...  Stopped running "user-command": exit st...  04-09 04:15:10
# phase-22-aou...  Stopped running "user-command": exit st...  04-09 02:56:39
# phase-22-aou...  Stopped running "user-command": exit st...  04-09 01:09:21
# phase-13-aou     Stopped running "user-command": exit st...  04-05 04:16:41
# phase-22-aou     Stopped running "user-command": exit st...  04-05 00:13:19
# phase-22-aou     Stopped running "user-command": exit st...  04-04 22:31:27
# phase-22-aou     Stopped running "user-command": exit st...  04-04 20:12:14
# phase-22-aou     Stopped running "user-command": exit st...  04-04 19:07:29
# phase-22-aou     Stopped running "localization": exit st...  04-04 16:40:50
# phase-22-aou     Stopped running "user-command": exit st...  04-04 15:37:44
# phase-22         Stopped running "localization": exit st...  04-04 04:34:54
# phase-mini22     The operation was cancelled                 04-03 18:32:57
# bcftools         Success                                     04-03 01:09:16
# plink2           Stopped running "localization": exit st...  04-02 23:27:35
# bcftools         Success                                     04-02 21:08:43
# bcftools         Stopped running "localization": exit st...  04-01 16:17:23
# bcftools         Stopped running "user-command": exit st...  04-01 02:52:19
# bcftools         Success                                     04-01 06:16:29
# bcftools         Success                                     03-31 19:55:01
# bcftools         The operation was cancelled                 03-31 09:40:16
# bcftools         Stopped running "user-command": exit st...  03-31 03:30:36
# bcftools         The operation was cancelled                 03-31 01:13:59
# bcftools         Stopped running "localization": exit st...  03-31 01:04:54
# gzip             Success                                     03-28 06:37:21
# bcftools         Stopped running "user-command": exit st...  03-27 21:05:25
# bcftools         Stopped running "user-command": exit st...  03-27 17:08:19
# bcftools         Success                                     03-27 18:11:40
# bcftools         Success                                     03-27 06:34:23
# bcftools         pulling image: docker pull: retry budge...  03-25 21:24:07
# bcftools         Stopped running "user-command": exit st...  03-25 20:40:09
# plink2           Success                                     03-25 07:51:51
# plink2           The operation was cancelled                 03-25 01:53:14
# plink2           Stopped running "user-command": exit st...  03-24 23:20:05
# plink2           Stopped running "user-command": exit st...  03-24 19:33:03
# plink2-filt-...  Success                                     03-24 17:34:15
# plink2-filt-...  Stopped running "user-command": exit st...  03-19 22:49:06
# plink2-snplist   Stopped running "user-command": exit st...  03-19 02:36:23
# plink2-snplist   Stopped running "user-command": exit st...  03-19 02:36:21
# plink2-snplist   Stopped running "user-command": exit st...  03-19 02:36:45
# plink2-snplist   Stopped running "user-command": exit st...  03-19 02:36:37
# plink2-snplist   Stopped running "user-command": exit st...  03-19 02:36:42
# plink2-snplist   Stopped running "localization": exit st...  03-19 00:26:50
# plink2-snplist   Stopped running "localization": exit st...  03-19 00:24:01
# plink2-snplist   Stopped running "localization": exit st...  03-19 00:26:35
# plink2-snplist   Stopped running "localization": exit st...  03-19 00:26:00
# plink2-snplist   Stopped running "localization": exit st...  03-19 00:27:25
# plink2-hwe       Success                                     03-18 18:38:26
# plink2-hwe       Success                                     03-18 18:33:32
# plink2-hwe       Success                                     03-18 19:13:17
# plink2-hwe       Success                                     03-18 18:30:15
# plink2-hwe       Success                                     03-18 18:43:55
# plink2-filt-...  Success                                     03-18 04:32:39
# plink2-filt-...  Success                                     03-18 04:33:10
# plink2-filt-...  Success                                     03-18 04:44:21
# plink2-filt-eas  Success                                     03-17 20:32:37
# plink2-filt      Success                                     03-17 19:38:09
# plink2-filt      pulling image: docker pull: retry budge...  03-17 17:14:53
# plink2-filt      pulling image: docker pull: retry budge...  03-17 16:49:34
# plink2-filt      pulling image: docker pull: retry budge...  03-17 16:49:26
# plink2-filt      pulling image: docker pull: retry budge...  03-17 16:46:52
